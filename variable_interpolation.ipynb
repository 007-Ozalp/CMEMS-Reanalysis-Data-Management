# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %%
import os
import sys
import pandas as pd

# %%
fn_temp = '/Volumes/Nereide/dataset/CMEMS_REANALYSIS/TEMPERATURE_SINCE_1999/2014_daily_cmems_reanalysis_temperature_AdriaticSea.nc'

temp_nc=[os.path.join(fn_temp) for f in fn_temp]

temp_ds=[xr.open_dataset(nc) for nc in temp_nc]

j=0

# %%
lon_name   = 'lon'
lat_name   = 'lat'
time_name  = 'time'
depth_name = 'depth'
temperature       = 'thetao'

# %%
z1 = np.array([5,10,20,40,100,200,300,400,500,1000])

tx = temp_ds[j].interp(depth=z1, method="linear")
#tx1 = tx.interp(depth=z1,lat=lat_sel,lon=lon_sel, method="linear")

tx
# Out:
# <xarray.Dataset>
# Dimensions:  (depth: 10, lat: 216, lon: 241, time: 365)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-01-01T12:00:00 ... 2014-12-31T12:00:00
#   * lat      (lat) float32 37.02 37.06 37.1 37.15 ... 45.85 45.9 45.94 45.98
#   * lon      (lon) float32 12.0 12.04 12.08 12.12 ... 21.88 21.92 21.96 22.0
#   * depth    (depth) int64 5 10 20 40 100 200 300 400 500 1000
# Data variables:
#     thetao   (time, depth, lat, lon) float64 15.86 15.85 15.85 ... nan nan nan
# Attributes:
#     Conventions:  CF-1.8

# %%
tx.depth
# Out:
# <xarray.DataArray 'depth' (depth: 10)>
# array([   5,   10,   20,   40,  100,  200,  300,  400,  500, 1000])
# Coordinates:
#   * depth    (depth) int64 5 10 20 40 100 200 300 400 500 1000
# Attributes:
#     units:          m
#     standard_name:  depth
#     long_name:      depth
#     axis:           Z
#     positive:       down

# %%
new_filename_2 = '2014_daily_cmems_reanalysis_temperature_AdriaticSea_Z10_.nc'
print ('saving to ', new_filename_2)
tx.to_netcdf(path=new_filename_2)
print ('finished saving')
# Out:
# saving to  2014_daily_cmems_reanalysis_temperature_AdriaticSea_Z10_.nc
# finished saving

# %%
import cf
cf.__version__
# Out:
# '3.9.0'

# %%
cf.CF()
# Out:
# '1.8'

# %%
import cf, cfplot as cfp

# %%
temp_ds_new = cf.read('2014_daily_cmems_reanalysis_temperature_AdriaticSea_Z10_.nc')[0]

# %%
#f_new.dump()

# %%
cf.write(temp_ds_new, '2014_daily_cmems_reanalysis_temperature_AdriaticSea_Z10_CF.nc')

# %%
temp_ds_new.dump()
# Out:
# -----------------------------------------------------
# Field: sea_water_potential_temperature (ncvar%thetao)
# -----------------------------------------------------
# Conventions = 'CF-1.8'
# _FillValue = nan
# long_name = 'potential temperature'
# standard_name = 'sea_water_potential_temperature'
# units = 'degrees_C'
# valid_max = 40.0
# valid_min = 1.0
#
# Data(time(365), depth(10), latitude(216), longitude(241)) = [[[[15.864423343155135, ..., --]]]] degrees_C
#
# Domain Axis: depth(10)
# Domain Axis: latitude(216)
# Domain Axis: longitude(241)
# Domain Axis: time(365)
#
# Dimension coordinate: time
#     axis = 'T'
#     calendar = 'proleptic_gregorian'
#     long_name = 'time'
#     standard_name = 'time'
#     units = 'days since 2014-01-01T12:00:00'
#     Data(time(365)) = [2014-01-01 12:00:00, ..., 2014-12-31 12:00:00] proleptic_gregorian
#
# Dimension coordinate: depth
#     axis = 'Z'
#     long_name = 'depth'
#     positive = 'down'
#     standard_name = 'depth'
# ...

# %%
print(temp_ds_new)
# Out:
# Field: sea_water_potential_temperature (ncvar%thetao)
# -----------------------------------------------------
# Data            : sea_water_potential_temperature(time(365), depth(10), latitude(216), longitude(241)) degrees_C
# Dimension coords: time(365) = [2014-01-01 12:00:00, ..., 2014-12-31 12:00:00] proleptic_gregorian
#                 : depth(10) = [5, ..., 1000] m
#                 : latitude(216) = [37.02083206176758, ..., 45.97916793823242] degrees_north
#                 : longitude(241) = [12.0, ..., 22.0] degrees_east
