# %%
import plotly.express as px
import xarray as xr
import os
import sys
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash import Dash, dcc, html, Input, Output  

import pandas as pd

df = pd.read_csv('2D_1day1.csv')
# Out:
# C:\Users\ozle_\AppData\Local\Temp/ipykernel_14700/3220918092.py:12: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\ozle_\AppData\Local\Temp/ipykernel_14700/3220918092.py:13: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %% [markdown]
# ![image.png](attachment:0b728ae4-7326-4873-9b9a-5e8924a94557.png)

# %%
fig = go.Figure(data=go.Scattergeo(
    lat = df['lat'][:],
    lon = df['lon'][:],
    text = df['time'] + '' + df['thetao'].astype(str) + ' T[C]',

    marker = dict(
        color = df['thetao'],
        reversescale = False,
        opacity = 1,
        size = 2,
        colorbar = dict(
            titleside = "right",
            outlinecolor = "rgba(68, 68, 68, 0)",
            ticks = "outside",
            #showticksuffix = "last",
            dtick = 1
        )
    )
))


fig=fig.update_layout(
    geo = dict(
        scope = 'europe',
        resolution = 50,
        showcoastlines=True, coastlinecolor="RebeccaPurple",
        showland=True, landcolor="LightGreen",
        showocean=True, oceancolor="LightBlue",
        showlakes=True, lakecolor="Blue",
        showrivers=True, rivercolor="Blue",
        projection = dict(
            type = 'natural earth',
            
            rotation_lon = None
        ),
        lonaxis = dict(
            showgrid = True,
            gridwidth = 0.5,
            range= [ 12, 22 ],
            dtick = 3
        ),
        lataxis = dict (
            showgrid = True,
            gridwidth = 0.5,
            range= [ 37, 46 ],
            dtick = 3
        )
    ),
    
   



)
fig.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})

app = dash.Dash(__name__)
app.layout = html.Div(
    [html.H1("16 November 2020 @5 m: \n Temperature Sea PHY Analysis"), dcc.Graph(figure=fig),]
)
if __name__ == "__main__":
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Nov/2021 14:22:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Nov/2021 14:22:47] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Nov/2021 14:22:47] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Nov/2021 14:22:47] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Nov/2021 14:22:47] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -

# %% [markdown]
# ![ezgif.com-gif-maker (1).gif](attachment:678ad964-d065-46e1-be17-b967c7f5ce7e.gif)
