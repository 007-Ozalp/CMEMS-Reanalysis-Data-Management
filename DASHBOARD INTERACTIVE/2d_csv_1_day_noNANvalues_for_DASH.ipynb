# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import sys
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd

# %%
fn_temp = '2019-11-16T12_00_00_DailyNovember_temp_AdriaticSea_@VL5m_CF.nc' # THETAO all daily June 10 days and depths
nut_ds = xr.open_dataset(os.path.join(fn_temp))

nut_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lat: 216, lon: 241)
# Coordinates:
#   * time     (time) datetime64[ns] 2019-11-16T12:00:00
#     depth    int64 ...
#   * lat      (lat) float32 37.02 37.06 37.1 37.15 ... 45.85 45.9 45.94 45.98
#   * lon      (lon) float32 12.0 12.04 12.08 12.12 ... 21.88 21.92 21.96 22.0
# Data variables:
#     thetao   (time, lat, lon) float64 ...
# Attributes:
#     Conventions:                     CF-1.8
#     source:                          MFS EAS6
#     contact:                         servicedesk.cmems@mercator-ocean.eu
#     title:                           Potential Temperature (3D) - Daily Mean
#     _CoordSysBuilder:                ucar.nc2.dataset.conv.CF1Convention
#     FROM_ORIGINAL_FILE__field_type:  daily_mean_centered_at_time_field
#     bulletin_type:                   forecast
#     bulletin_date:                   20210509
#     history:                         Data extracted from dataset http://local...
# ...

# %%
df = nut_ds.to_dataframe()
df
# Out:
#                                          depth     thetao
# time                lat       lon
# 2019-11-16 12:00:00 37.020832 12.000000      5  19.522719
#                               12.041667      5  19.651032
#                               12.083333      5  19.674173
#                               12.125000      5  19.643954
#                               12.166667      5  19.594936
# ...                                        ...        ...
#                     45.979168 21.833334      5        NaN
#                               21.875000      5        NaN
#                               21.916666      5        NaN
#                               21.958334      5        NaN
#                               22.000000      5        NaN
#
# [52056 rows x 2 columns]

# %%
#eliminate NAN values from dataframe

kk=df.dropna()
kk
# Out:
#                                          depth     thetao
# time                lat       lon
# 2019-11-16 12:00:00 37.020832 12.000000      5  19.522719
#                               12.041667      5  19.651032
#                               12.083333      5  19.674173
#                               12.125000      5  19.643954
#                               12.166667      5  19.594936
# ...                                        ...        ...
#                     45.687500 13.708333      5  16.221512
#                     45.729168 13.541667      5  16.457306
#                               13.583333      5  16.292941
#                               13.625000      5  16.018023
#                               13.666667      5  15.925556
#
# [23573 rows x 2 columns]

# %%
kk.to_csv("2D_1day1.csv", index=True, header=True)
