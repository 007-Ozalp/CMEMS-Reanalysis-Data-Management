# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

# %%
import os
import sys
import pandas as pd
import pathlib
from pathlib import Path

# %%
for chl_file in os.listdir('/Volumes/Nereide/dataset/CMEMS_REANALYSIS/WAVES_SINCE_1993/WAVES_DATASET_2'):
    if chl_file.endswith('.nc'):
        print(chl_file)
# Out:
# 2015_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2003_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2012_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2004_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 1995_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2005_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2013_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2002_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2014_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 1994_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 1993_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 1997_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# 2008_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc
# ...

# %%
pft_nc=[os.path.join(chl_file) for f in chl_file]

#pft_ds=[xr.open_dataset(nc) for nc in pft_nc]

pft_ds=xr.open_mfdataset('/Volumes/Nereide/dataset/CMEMS_REANALYSIS/WAVES_SINCE_1993/WAVES_DATASET_2/2018_cmems_waves_hourly_reanalysis_mean_peak_direction_AdriaticSea.nc', parallel=True)

# %%
pft_ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 216, longitude: 240, time: 8760)
# Coordinates:
#   * latitude   (latitude) float32 37.02 37.06 37.1 37.15 ... 45.9 45.94 45.98
#   * longitude  (longitude) float32 12.0 12.04 12.08 12.13 ... 21.88 21.92 21.96
#   * time       (time) datetime64[ns] 2018-01-01 ... 2018-12-31T23:00:00
# Data variables:
#     VMDR       (time, latitude, longitude) float32 dask.array<chunksize=(8760, 216, 240), meta=np.ndarray>
#     VPED       (time, latitude, longitude) float32 dask.array<chunksize=(8760, 216, 240), meta=np.ndarray>
# Attributes: (12/13)
#     bulletin_type:  reanalysis
#     institution:    Hellenic Centre for Marine Research (HCMR)- Athens,Greece
#     source:         MEDWAM3
#     credit:         Copernicus Marine Environment Monitoring Service (CMEMS)
#     contact:        servicedesk.cmems@mercator-ocean.eu
#     producer:       CMEMS-MED Monitoring and Forecasting Centre
#     ...             ...
# ...

# %%
t=pft_ds.get(['VMDR'])

# %%
k = t.sel(latitude=slice(37, 46), longitude=slice(12, 22)) ###Adriatic Box

# %%
k
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 216, longitude: 240, time: 8760)
# Coordinates:
#   * latitude   (latitude) float32 37.02 37.06 37.1 37.15 ... 45.9 45.94 45.98
#   * longitude  (longitude) float32 12.0 12.04 12.08 12.13 ... 21.88 21.92 21.96
#   * time       (time) datetime64[ns] 2018-01-01 ... 2018-12-31T23:00:00
# Data variables:
#     VMDR       (time, latitude, longitude) float32 dask.array<chunksize=(8760, 216, 240), meta=np.ndarray>
# Attributes: (12/13)
#     bulletin_type:  reanalysis
#     institution:    Hellenic Centre for Marine Research (HCMR)- Athens,Greece
#     source:         MEDWAM3
#     credit:         Copernicus Marine Environment Monitoring Service (CMEMS)
#     contact:        servicedesk.cmems@mercator-ocean.eu
#     producer:       CMEMS-MED Monitoring and Forecasting Centre
#     ...             ...
#     comment:        Please check in CMEMS catalogue the INFO section for prod...
#     Conventions:    CF-1.6
#     area:           MED
# ...

# %%
new_filename_1 = '/Volumes/Nereide/dataset/CMEMS_REANALYSIS/WAVES_SINCE_1993/WAVES_DATASET_2/WAVES_VMDR/2018_cmems_waves_hourly_reanalysis_vmdr_AdriaticSea.nc'
print ('saving to ', new_filename_1)
#t_uo.to_netcdf(path=new_filename_1)
#t_vo.to_netcdf(path=new_filename_1)
k.to_netcdf(path=new_filename_1)

print ('finished saving')
# Out:
# saving to  /Volumes/Nereide/dataset/CMEMS_REANALYSIS/WAVES_SINCE_1993/WAVES_DATASET_2/WAVES_VMDR/2018_cmems_waves_hourly_reanalysis_vmdr_AdriaticSea.nc
# finished saving

# %%
fn_chl_new1 = '/Volumes/Nereide/dataset/CMEMS_REANALYSIS/WAVES_SINCE_1993/WAVES_DATASET_2/WAVES_VMDR/2018_cmems_waves_hourly_reanalysis_vmdr_AdriaticSea.nc' # THETAO all 12 months and depths


pft_nc_new1 = [os.path.join(fn_chl_new1) for f in fn_chl_new1]
pf_new_ds1 = [ xr.open_dataset(nc) for nc in pft_nc_new1]

j = 0
pf_new_ds1[j]
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 216, longitude: 240, time: 8760)
# Coordinates:
#   * latitude   (latitude) float32 37.02 37.06 37.1 37.15 ... 45.9 45.94 45.98
#   * longitude  (longitude) float32 12.0 12.04 12.08 12.13 ... 21.88 21.92 21.96
#   * time       (time) datetime64[ns] 2018-01-01 ... 2018-12-31T23:00:00
# Data variables:
#     VMDR       (time, latitude, longitude) float32 ...
# Attributes: (12/13)
#     bulletin_type:  reanalysis
#     institution:    Hellenic Centre for Marine Research (HCMR)- Athens,Greece
#     source:         MEDWAM3
#     credit:         Copernicus Marine Environment Monitoring Service (CMEMS)
#     contact:        servicedesk.cmems@mercator-ocean.eu
#     producer:       CMEMS-MED Monitoring and Forecasting Centre
#     ...             ...
#     comment:        Please check in CMEMS catalogue the INFO section for prod...
#     Conventions:    CF-1.6
#     area:           MED
#     bulletin_date:  2020-06-01
# ...
