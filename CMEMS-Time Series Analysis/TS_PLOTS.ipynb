# %% [markdown]
# # CMEMS Reanalysis Model datasets, Temperature at Sea Surface from 1987 to 2019
# ## File types for Temperature at Sea Surface: 1D: .csv <br>
# ### Box, violin and cat plots
#
# Prefered library is Seaborn
#
# <ol>
# <li>Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea</li>
# <li>Temperature at Sea Surfacefrom 1987 to 2019 over Adriatic Sea\nAnnual Boxplot</li>
# <li>Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea\nMonthly Boxplot</li>
# <li>Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea\nMonthly Violin plot</li>
# <li>Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea\nMonthly Cat plot</li>
#
#
# </ol>

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse 
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
from cycler import cycler

# %%
rcParams['figure.figsize'] = 18, 10
rcParams['lines.linewidth'] = 3

df = pd.read_csv('TS_cmems_reanalysis_temperature_from1987to2019_AdriaticSea.csv', index_col='DATE', parse_dates=['DATE'])

plt.title('Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea', size=20)

plt.plot(df, color='k', label='Original')
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.legend();

# %%
#df['year'] 
#df['month']

# %%
df
# Out:
#                      TEMPERATURE
# DATE
# 1987-01-01 12:00:00    14.696689
# 1987-01-02 12:00:00    14.670896
# 1987-01-03 12:00:00    14.636758
# 1987-01-04 12:00:00    14.561996
# 1987-01-05 12:00:00    14.448793
# ...                          ...
# 2019-12-27 12:00:00    16.640701
# 2019-12-28 12:00:00    16.531431
# 2019-12-29 12:00:00    16.363058
# 2019-12-30 12:00:00    16.206219
# 2019-12-31 12:00:00    16.103290
#
# [12053 rows x 1 columns]

# %%
df = pd.read_csv('TS_cmems_reanalysis_temperature_from1987to2019_AdriaticSea.csv', parse_dates=['DATE'])
df.reset_index(inplace=True)

df['Time Series from 1987 to 2019'] = [d.year for d in df.DATE]
df['month'] = [d.strftime('%b') for d in df.DATE]
years = df['Time Series from 1987 to 2019'].unique()

fig, axes = plt.subplots(1, figsize=(20,12), dpi= 100)
sns.boxplot(x='Time Series from 1987 to 2019', y='TEMPERATURE', data=df, palette="tab10")

axes.set_title('Temperature at Sea Surfacefrom 1987 to 2019 over Adriatic Sea Annual\nBoxplot', fontsize=20); 
#plt.savefig('Temperatureat Sea Surface-Annual Boxplot.png')
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()
plt.close()

# %%
df['Time Series from 1987 to 2019'] = [d.year for d in df.DATE]
df['Month'] = [d.strftime('%b') for d in df.DATE]
years = df['Time Series from 1987 to 2019'].unique()

fig, axes = plt.subplots(1, figsize=(18,8), dpi= 100)
sns.boxplot(x='Month', y='TEMPERATURE', data=df.loc[~df.month.isin([1987, 2019]), :], palette="tab10")

axes.set_title('Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea Monthly\nBoxplot', fontsize=20); 
#plt.savefig('Temperature at Sea Surface-Monthly Boxplot.png')
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.show()
plt.close()

# %%
plt.style.use('seaborn')

df['Time Series from 1987 to 2019'] = [d.year for d in df.DATE]
df['Month'] = [d.strftime('%b') for d in df.DATE]
years = df['Time Series from 1987 to 2019'].unique()

fig, axes = plt.subplots(1, figsize=(18,8), dpi= 100)
#sns.boxplot(x='Month', y='TEMPERATURE', data=df.loc[~df.month.isin([1987, 2019]), :], palette="tab10")
sns.violinplot(x='Month', y='TEMPERATURE', data=df.loc[~df.month.isin([1987, 2019]), :], palette="tab10", bw=.2, cut=1, linewidth=1)

axes.set_title('Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea Monthly\nViolin plot', fontsize=20); 
#plt.savefig('Temperature at Sea Surface-Monthly Boxplot.png')
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.show()
plt.close()

# %%
plt.style.use('seaborn')

df['Time Series from 1987 to 2019'] = [d.year for d in df.DATE]
df['Month'] = [d.strftime('%b') for d in df.DATE]
years = df['Time Series from 1987 to 2019'].unique()

fig, axes = plt.subplots(1, figsize=(18,8), dpi= 100)
sns.histplot(
    x='Month', y='TEMPERATURE', data=df.loc[~df.month.isin([1987, 2019]), :],
    multiple="stack",
    palette="tab10",
)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='TEMPERATURE'>

# %%
plt.style.use('seaborn')

df['Time Series from 1987 to 2019'] = [d.year for d in df.DATE]
df['Month'] = [d.strftime('%b') for d in df.DATE]
years = df['Time Series from 1987 to 2019'].unique()


sns.catplot(
    x='Month', y='TEMPERATURE', data=df.loc[~df.month.isin([1987, 2019]), :],
    ci="sd", palette="dark",alpha=.9, height=10,aspect=18/10
)
#axes.set_title('Temperature at Sea Surface-Monthly Catplot', fontsize=15); 
plt.title('Temperature at Sea Surface from 1987 to 2019 over Adriatic Sea Monthly\nCat plot', size=20)
plt.xticks(size = 20)
plt.yticks(size = 20)
#plt.savefig('Temperature at Sea Surface-Monthly catplot.png')
plt.show()
plt.close()
